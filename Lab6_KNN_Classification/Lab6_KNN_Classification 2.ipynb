# %% [markdown]
# # Lab 6 – KNN Classification
# Student: Khushi Danagoudar
# Course: Data Science Lab
#
# This notebook trains and compares three models:
# - KNN Classifier
# - Logistic Regression
# - Decision Tree Classifier

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# ## Load Dataset

# %%
train = pd.read_csv('train_KNN.csv')
test = pd.read_csv('test_KNN.csv')

train.head()

# %% [markdown]
# ## Prepare Features and Target

# %%
X_train = train.drop('Survived', axis=1)
y_train = train['Survived']

X_test = test.drop('Survived', axis=1)
y_test = test['Survived']

# %% [markdown]
# ## KNN Model

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)

knn_pred = knn.predict(X_test)
print('KNN Accuracy:', accuracy_score(y_test, knn_pred))

# %% [markdown]
# ## Logistic Regression

# %%
log_model = LogisticRegression(max_iter=1000)
log_model.fit(X_train, y_train)

log_pred = log_model.predict(X_test)
print('Logistic Regression Accuracy:', accuracy_score(y_test, log_pred))

# %% [markdown]
# ## Decision Tree

# %%
tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)

tree_pred = tree.predict(X_test)
print('Decision Tree Accuracy:', accuracy_score(y_test, tree_pred))

# %% [markdown]
# ## Model Comparison

# %%
print('\nClassification Report (KNN)')
print(classification_report(y_test, knn_pred))

# %% [markdown]
# ## Conclusion
# Compare the accuracies of KNN, Logistic Regression, and Decision Tree models to determine which performs best for the Titanic survival prediction dataset.
