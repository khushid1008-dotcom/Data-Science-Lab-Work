# %% [markdown]
# # Intermediate Machine Learning Project
# Author: Khushi Danagoudar
# Basic data analysis using Python and Pandas.

# %%
import pandas as pd

data = {'Name':['Alice','Bob','Charlie'], 'Score':[85,90,78]}
df = pd.DataFrame(data)
print(df)
