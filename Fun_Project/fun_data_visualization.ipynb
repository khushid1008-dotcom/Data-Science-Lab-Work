# %% [markdown]
# # Fun Project - Simple Data Visualization
# Author: Khushi Danagoudar
# This project visualizes simple data using Python.

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [2,4,6,8,10]

plt.plot(x,y)
plt.title('Simple Line Chart')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.show()
