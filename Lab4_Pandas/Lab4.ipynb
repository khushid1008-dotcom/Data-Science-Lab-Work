# %% [markdown]
# # Lab 4 – Pandas
# Student: Khushi Danagoudar
# Course: Data Science Lab
#
# This notebook demonstrates basic Pandas operations including loading data, exploring the dataset, and performing simple analysis.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Create Sample DataFrame

# %%
data = {
    'Student': ['A', 'B', 'C', 'D', 'E'],
    'Math': [78, 85, 96, 67, 88],
    'Science': [90, 89, 94, 70, 85],
    'English': [85, 78, 88, 72, 90]
}

df = pd.DataFrame(data)
df

# %% [markdown]
# ## Dataset Information

# %%
df.info()

# %% [markdown]
# ## Statistical Summary

# %%
df.describe()

# %% [markdown]
# ## Calculate Average Marks

# %%
df['Average'] = df[['Math','Science','English']].mean(axis=1)
df

# %% [markdown]
# ## Sort Students by Average Score

# %%
df.sort_values(by='Average', ascending=False)
